# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
osaka = pd.read_csv('osaka_tripadvisor.csv')
osaka.head()
# Out:
#                                name  \
# 0                          Yakumido
# 1                 Hokuto GEMS Namba
# 2               Okonomiyaki Chitose
# 3           Gyukatsu Motomura Namba
# 4  Dotonbori Riverside Grill Wonder
#
#                                              address  rankingPosition  \
# 0  2-2-10 Haginochaya, Nishinari-Ku, Osaka 557-00...                1
# 1  3-7-19 Gems Namba 7F, Namba, Chuo, Osaka 539-0...                1
# 2  1-11-10 Taishi, Nishinari-ku, Osaka 557-0002 O...                7
# 3  3-3-1 Sugata Bldg B1F, Namba, Chuo, Osaka 542-...                2
# 4  1-1-6 Riverside B1F, Dotombori, Chuo, Osaka 54...                2
#
#    rawRanking priceLevel  numberOfReviews       priceRange  \
# 0    4.779569          $              173    $500 - $1,000
# 1    4.732521   $$ - $$$              539  $1,000 - $4,000
# 2    4.701214          $              559              NaN
# 3    4.693217   $$ - $$$              392  $1,000 - $3,000
# ...
