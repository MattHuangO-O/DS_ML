# %%
import pandas as pd
stock = pd.read_csv(r"C:\Users\19hua\Desktop\Computer Science\Great Learning\Week 1\StockData.csv")
stock.head()
stock.info()
stock["stock"].value_counts()
stock.describe()
stock.groupby(["stock"])["price"].mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5036 entries, 0 to 5035
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   stock   5036 non-null   object
#  1   date    5036 non-null   object
#  2   price   5036 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 118.2+ KB
# stock
# AAPL    109.066698
# SNI      71.319206
# TJX      66.743566
# ZTS      45.098648
# Name: price, dtype: float64

# %%
from IPython.display import Image

# %%
import pandas as pd
import matplotlib as mp
import seaborn as sns

auto = pd.read_csv(r"C:\Users\19hua\Desktop\Computer Science\Great Learning\Week 1\Automobile.csv")
auto.head()
auto.describe(include = "all").T
# Out:
#                      count unique     top freq          mean          std
# symboling            201.0    NaN     NaN  NaN      0.840796     1.254802  \
# normalized_losses    201.0    NaN     NaN  NaN    125.189055    33.572966
# make                   201     22  toyota   32           NaN          NaN
# fuel_type              201      2     gas  181           NaN          NaN
# aspiration             201      2     std  165           NaN          NaN
# number_of_doors        201      2    four  114           NaN          NaN
# body_style             201      5   sedan   94           NaN          NaN
# drive_wheels           201      3     fwd  118           NaN          NaN
# engine_location        201      2   front  198           NaN          NaN
# wheel_base           201.0    NaN     NaN  NaN     98.797015     6.066366
# length               201.0    NaN     NaN  NaN    174.200995    12.322175
# width                201.0    NaN     NaN  NaN     65.889055     2.101471
# ...

# %%
#sns.histplot(auto, x = "horsepower", kde = True)
sns.countplot(data = auto, x = "body_style", hue = "fuel_system")
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
sns.jointplot(data = auto, x = "horsepower", y = "engine_size", kind = "hex")

# %%
import pandas as pd
score = [10, 15, 20, 25]
pd.Series(data=score, index = ['a','b','c','d'])
# Out:
# a    10
# b    15
# c    20
# d    25
# dtype: int64
